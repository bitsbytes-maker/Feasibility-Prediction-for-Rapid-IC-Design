# %%
#Six curves for five variables matrix (10x5).... Max vs Min
from numpy import random
import matplotlib.pyplot as plt 
import numpy as np


def getMaxIndex(x):
  indexFirst = 0 
  indexSecond = 0
  max = x[0]
  for i in range(len(x)):
    if max <= x[i]:
      max = x[i]
      indexFirst = i
  
  x[indexFirst] = -1*max
  max = x[0]

  for i in range(len(x)):
    if max <= x[i]:
      max = x[i]
      indexSecond = i



  return indexFirst,indexSecond 


def squr(x,y):
  return x*x - y*y

def drawCurve(x,y):
  plt.figure(figsize=(10,10))
  #plt.scatter(x,y, s= 20) # for changing it to scatter plt.scatter() and keep the s which is point size
  plt.plot(x,y)  # for changing it to striaght line plt.plot() and omit the s which is point size
  for i in range(len(x)):
    plt.annotate(str(i), (x[i],y[i]), size = 20)
  plt.xlabel(str(x))
  plt.ylabel(str(y))

x = random.randint(100, size=(10, 5))
print(x)

# x for maximizing and  y for minimizing
x0,x1,x2,y3,y4 = [],[],[],[],[]

#0,1..4 that's are coulumn number
o1,o2,o3,o4,o5,o6 = [],[],[],[],[],[]

#It is the priority
a,b,c,d,e = 2,2,2,1,1

for i in range(len(x)):
  x0.append(a*x[i][0])
  x1.append(b*x[i][1])
  x2.append(c*x[i][2])
  y3.append(d*x[i][3])
  y4.append(e*x[i][4])


#Just keeping the value in array for furture use when data size is big or graph number will increase
array = np.arange(60).reshape(6,10)


#array and o1,o2,o3,o4,o5,o6 are same task doing
for i in range(len(x)):
  o1.append(squr(x0[i],y3[i]))
  array[0][i] = squr(x0[i],y3[i])
  o2.append(squr(x1[i],y3[i]))
  array[1][i] = squr(x1[i],y3[i])
  o3.append(squr(x2[i],y3[i]))
  array[2][i] = squr(x2[i],y3[i])
  o4.append(squr(x0[i],y4[i])) 
  array[3][i] = squr(x0[i],y4[i])
  o5.append(squr(x1[i],y4[i])) 
  array[4][i] = squr(x1[i],y4[i])
  o6.append(squr(x2[i],y4[i]))
  array[5][i] = squr(x2[i],y4[i])


# sList stores the solution list for counting the maximum occurence 79 to 93
sList = []
for i in range(6):
  one,two = getMaxIndex(array[i]) 
  sList.append(one)
  #sList.append(two)


print(array)

maxCount = []
for i in range(len(sList)):
  maxCount.append(sList.count(sList[i]))

maxOcurring = np.max(maxCount)
print("Our best solution may be")
print(sList[maxCount.index(maxOcurring)])
  


print('From the list')
print(sList)


print(o1)
print(o2)
print(o3)
print(o4)
print(o5)
print(o6)

print(str(getMaxIndex(o1))+"  "+str(getMaxIndex(o2))+" "+str(getMaxIndex(o3))+" "+
      str(getMaxIndex(o4))+" "+str(getMaxIndex(o5))+" "+str(getMaxIndex(o6)))


smplNo = [i for i in range(len(x))]

drawCurve(smplNo,o1)
drawCurve(smplNo,o2)
drawCurve(smplNo,o3)
drawCurve(smplNo,o4)
drawCurve(smplNo,o5)
drawCurve(smplNo,o6)
# Out:
# [[81 31 41 24 69]
#  [88 10  3 53 52]
#  [84 47 31 48  8]
#  [43 62 39 46 60]
#  [ 2 56 26 39 37]
#  [83 61 12 24 46]
#  [79 49 89 23 61]
#  [40 30 25 34 89]
#  [28 72 58  7 85]
#  [95 75 77 24 16]]
# [[ 25668  28167  25920   5280  -1505  26980  24435   5244   3087 -35524]
#  [  3268  -2409   6532  13260  11023  14308   9075   2444  20687 -21924]
#  [  6148  -2773   1540   3968   1183      0 -31155   1344  13407  23140]
#  [ 21483  28272  28160   3796  -1353  25440  21243  -1521  -4089 -35844]
#  [  -917  -2304   8772  11776  11175  12768   5883  -4321  13511 -22244]
#  [  1963  -2668   3780   2484   1335  -1540 -27963  -5421   6231  23460]]
# Our best solution may be
# 9
# From the list
# [9, 9, 6, 9, 9, 6]
# [25668, 28167, 25920, 5280, -1505, 26980, 24435, 5244, 3087, 35524]
# [3268, -2409, 6532, 13260, 11023, 14308, 9075, 2444, 20687, 21924]
# [6148, -2773, 1540, 3968, 1183, 0, 31155, 1344, 13407, 23140]
# [21483, 28272, 28160, 3796, -1353, 25440, 21243, -1521, -4089, 35844]
# [-917, -2304, 8772, 11776, 11175, 12768, 5883, -4321, 13511, 22244]
# [1963, -2668, 3780, 2484, 1335, -1540, 27963, -5421, 6231, 23460]
# (9, 1)  (9, 8) (6, 9) (9, 1) (9, 8) (6, 9)

# %%
#Objective function = Rmax - Rmin for 5 variables just here for experiment


import matplotlib.pyplot as plt 
from numpy import random

def squrroot(x,y,z=0):
  return (x**2+y**2+z**2)**0.5


print(x)


front = x[0]
print("Square root")

maxList = []
minList = []
a,b,c,d,e = 2,2,2,1,1
# increasing the value of coeffiecen to maximize and decreasing to minimize

for i in range(len(x)):
  squr_root_max = squrroot(a*x[i][0],b*x[i][1],c*x[i][2])

  squr_root_min = squrroot(d*x[i][3],e*x[i][4])

  maxList.append(squr_root_max)
  minList.append(squr_root_min)

  print(str(i)+"  no row----->"+str(squrroot(x[i][0],x[i][1],x[i][2]))+"---->"+str(squrroot(x[i][3],x[i][4])))

index = 0
frontMax = maxList[0]
frontMin = minList[0]
for i in range(len(x)):
  
  if (maxList[i]- minList[i]) >= (frontMax - frontMin):
    frontMax = maxList[i]
    frontMin = minList[i]
    index = i

print('Approximate solution')
print(str(index)+" ..........is the soultion number")

plt.figure(figsize=(10,10))
plt.scatter(maxList, minList, s= 100)
for i in range(len(x)):
  plt.annotate(str(i), (maxList[i],minList[i]), size = 20)

plt.xlabel('MaxList')
plt.ylabel('MinList')


diffList = []
sampleNoList = [i for i in range(len(x))]
for i in range(len(x)):
  diffList.append(maxList[i] - minList[i])


plt.figure(figsize=(10,10))
plt.plot(sampleNoList, diffList)
for i in range(len(x)):
  plt.annotate(str(i), (sampleNoList[i],diffList[i]), size = 20)

plt.xlabel('Sample no')
plt.ylabel('Difference')
# Out:
# [[31 49 50  2 19]
#  [43  1 28 45 71]
#  [99 58 92 10 69]
#  [82 95  5 49 81]
#  [97 13 10 56 41]
#  [38  7 18 86 80]
#  [76 32 98 81 94]
#  [67 17 48 75 53]
#  [56 75 71 71 42]
#  [65 13 42  3 87]]
# Square root
# 0  no row----->76.56369897020389---->19.1049731745428
# 1  no row----->51.32250968142536---->84.05950273467003
# 2  no row----->147.06801147768334---->69.72087205421343
# 3  no row----->125.59458587057007---->94.66784036831093
# 4  no row----->98.37682653958706---->69.40461079784254
# 5  no row----->42.62628297189423---->117.45637488020819
# 6  no row----->128.07810117268292---->124.08464852672147
# 7  no row----->84.15461959987698---->91.83681179135085
# 8  no row----->117.48191350161096---->82.49242389456137
# 9  no row----->78.4729252672538---->87.05170877128145
# Approximate solution
# 2 ..........is the soultion number
# Text(0, 0.5, 'Difference')
