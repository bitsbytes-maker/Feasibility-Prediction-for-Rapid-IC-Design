# %%
#Objective function = Rmax - Rmin 


def squrroot(x,y,z=0):
  return (x**2+y**2+z**2)**0.5


import matplotlib.pyplot as plt 
from numpy import random
x = random.randint(100, size=(10, 5))
print(x)

front = x[0]
print("Square root")

maxList = []
minList = []

# increasing the value of coeffiecen to maximize and decreasing to minimize

for i in range(len(x)):
  squr_root_max = squrroot(x[i][0],x[i][1],x[i][4])

  squr_root_min = squrroot(x[i][2],x[i][3])

  maxList.append(squr_root_max)
  minList.append(squr_root_min)

  print(str(i)+"  no row----->"+str(squrroot(x[i][0],x[i][1],x[i][4]))+"---->"+str(squrroot(x[i][2],x[i][3])))

index = 0
frontMax = maxList[0]
frontMin = minList[0]
for i in range(len(x)):
  
  if (maxList[i]- minList[i]) >= (frontMax - frontMin):
    frontMax = maxList[i]
    frontMin = minList[i]
    index = i

print('Approximate solution')
print(str(index)+" ..........is the soultion number")

plt.figure(figsize=(10,10))
plt.scatter(maxList, minList, s= 100)
for i in range(len(x)):
  plt.annotate(str(i), (maxList[i],minList[i]), size = 20)

plt.xlabel('MaxList')
plt.ylabel('MinList')


diffList = []
sampleNoList = [i for i in range(len(x))]
for i in range(len(x)):
  diffList.append(maxList[i] - minList[i])


plt.figure(figsize=(10,10))
plt.plot(sampleNoList, diffList)
for i in range(len(x)):
  plt.annotate(str(i), (sampleNoList[i],diffList[i]), size = 20)

plt.xlabel('Sample no')
plt.ylabel('Difference')
# Out:
# [[26 95 35 21 43]
#  [55 70 66 28 88]
#  [32 36 54  5 94]
#  [91 70 67 68 21]
#  [34 92 17 24 28]
#  [21 22 26 70  7]
#  [57 24 53 59 32]
#  [45 73 25 46 10]
#  [88 91 92 24 25]
#  [97 72 76 82 13]]
# Square root
# 0  no row----->107.47092630102338---->40.8166632639171
# 1  no row----->125.1758762701504---->71.69379331573968
# 2  no row----->105.62196741208714---->54.230987451824994
# 3  no row----->116.71332400373147---->95.46203433826454
# 4  no row----->102.0---->29.410882339705484
# 5  no row----->31.20897306865447---->74.67261881037788
# 6  no row----->69.63476143421474---->79.30952023559341
# 7  no row----->86.3365507765975---->52.354560450833695
# 8  no row----->129.0348790056394---->95.0789145920377
# 9  no row----->121.49897118905987---->111.80339887498948
# Approximate solution
# 4 ..........is the soultion number
# Text(0, 0.5, 'Difference')

# %%
#Objective function = Rmax - Rmin having 10 variables with coefficient
import matplotlib.pyplot as plt 
from numpy import random

def squrRoot(x,y,z=0):
  return (x**2+y**2+z**2)**0.5


def optimalSolution(maxList,minList):
  index = 0
  frontMax = maxList[0]
  frontMin = minList[0]
  for i in range(len(x)):
  
    if (maxList[i]- minList[i]) >= (frontMax - frontMin):
      frontMax = maxList[i]
      frontMin = minList[i]
      index = i
  
  return index

x = random.randint(100, size=(10, 10))
print(x)


print("Square root with factoring")

maxList = []
minList = []

a,b,c,d = 2,3,0.9,0.9
# increasing the value of coeffiecent to maximize function and decreasing to minimize function

for i in range(len(x)):
  _max = a*squrRoot(x[i][0],x[i][1],x[i][2])+b*squrRoot(x[i][3],x[i][4],x[i][5])

  _min = c*squrRoot(x[i][6],x[i][7])+ d*squrRoot(x[i][8],x[i][9])

  maxList.append(_max)
  minList.append(_min)

  print(str(i)+"  no row----->"+str(_max)+ "---->" +str(_min))

print('Solution with factoring')
index = optimalSolution(maxList,minList)
print(str(index)+" ..........is the soultion number")

print('Without factoring square root')

maxList1 = []
minList1 = []
a,b,c,d =1,1,1,1
for i in range(len(x)):
  _max = a*squrRoot(x[i][0],x[i][1],x[i][2])+b*squrRoot(x[i][3],x[i][4],x[i][5])

  _min =c*squrRoot(x[i][6],x[i][7])+ d*squrRoot(x[i][8],x[i][9])

  maxList1.append(_max)
  minList1.append(_min)


  print(str(i)+"  no row----->"+str(_max)+"---->"+str(_min))

print('Solution without factoring')
index = optimalSolution(maxList1,minList1)
print(str(index)+" ..........is the soultion number")



plt.figure(figsize=(10,10))
plt.scatter(maxList, minList, s= 100)
for i in range(len(x)):
  plt.annotate(str(i), (maxList[i],minList[i]), size = 20)

plt.xlabel('MaxList')
plt.ylabel('MinList')


diffList = []
sampleNoList = [i for i in range(len(x))]
for i in range(len(x)):
  diffList.append(maxList[i] - minList[i])


plt.figure(figsize=(10,10))
plt.plot(sampleNoList, diffList)
for i in range(len(x)):
  plt.annotate(str(i), (sampleNoList[i],diffList[i]), size = 20)

plt.xlabel('Sample no')
plt.ylabel('Difference')
# Out:
# [[48 22 87 66 12 10 45 75 88  5]
#  [40 85 10 28 56 87  2 40 13 83]
#  [82 97 33 81 12  6 19 78 69 76]
#  [41 97 40 16 78 97 50 25 96 46]
#  [36 22 64 23 88  5 51 80  1 73]
#  [71 12 18 61  7 80 35 74 11 37]
#  [35 34 92 33 99  1 75 28 22 13]
#  [85 69 95 88  5 16 13 39 16 64]
#  [62  2 50 14 27 35 20  2 98  8]
#  [90 41 58 77 72 91 79 18 79 19]]
# Square root with factoring
# 0  no row----->407.00859360374784---->158.04558847832467
# 1  no row----->510.50469501545683---->111.65568543669102
# 2  no row----->508.7760150945101---->164.6375829749398
# 3  no row----->601.7848597307388---->146.11820984537837
# 4  no row----->426.590219286296---->151.0924042036806
# 5  no row----->450.9845297635971---->108.41413868484193
# 6  no row----->521.3585215085851---->95.04908542517671
# 7  no row----->558.6505252052227---->96.37136963286436
# 8  no row----->298.4529517287723---->106.58316570164695
# 9  no row----->647.0903196904775---->146.0496418730155
# Solution with factoring
# 9 ..........is the soultion number
# Without factoring square root
# 0  no row----->169.5926468862476---->175.60620942036076
# 1  no row----->201.65897105130426---->124.06187270743447
# 2  no row----->213.33621099704305---->182.9306477499331
# 3  no row----->238.1449199546168---->162.35356649486485
# 4  no row----->167.74843029108106---->167.88044911520063
# 5  no row----->175.0690559398837---->120.46015409426882
# 6  no row----->208.4992837516146---->105.61009491686302
# 7  no row----->234.53408043468903---->107.0792995920715
# 8  no row----->126.04242962564689---->118.42573966849662
# 9  no row----->253.91398866450965---->162.2773798589061
# Solution without factoring
# 7 ..........is the soultion number
# Text(0, 0.5, 'Difference')

# %%
#Six curves from 10 by 5 matrix.... Max vs Min

import matplotlib.pyplot as plt 

def drawCurve(x,y):
  plt.figure(figsize=(10,10))
  plt.scatter(x,y, s= 20) # for changing it to scatter plt.scatter() and keep the s which is point size
  #plt.plot(x,y)  # for changing it to striaght line plt.plot() and omit the s which is point size
  for i in range(len(x)):
    plt.annotate(str(i), (x[i],y[i]), size = 20)
  plt.xlabel(str(x))
  plt.ylabel(str(y))

x = random.randint(100, size=(10, 5))
print(x)

x0,x1,x2,y3,y4 = [],[],[],[],[]

#0,1..4 that's are coulumn number

for i in range(len(x)):
  x0.append(x[i][0])
  x1.append(x[i][1])
  x2.append(x[i][2])
  y3.append(x[i][3])
  y4.append(x[i][4])

 

drawCurve(x0,y3)
drawCurve(x1,y3)
drawCurve(x2,y3)
drawCurve(x0,y4)
drawCurve(x1,y4)
drawCurve(x2,y4)
# Out:
# [[92 47 10  6 41]
#  [91 21 65 23  0]
#  [54 70  6 42 54]
#  [22 52 17 31  5]
#  [23 96 11 11 70]
#  [56 34  5 82 68]
#  [42 42 50 35 16]
#  [68 92 86 54 70]
#  [69 91 81 54 34]
#  [27 39 12 83 34]]

# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
print(x)

px = []
py = []
pz = []

print('summ')
for i in range(len(x)):
  px.append(x[i][0])
  py.append(x[i][1])
  pz.append(x[i][4])
  print(str(i)+"---->"+str(px[i]+py[i]+pz[i]))



fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(px, py, pz,s = 100)
for i in range(len(x)):
  ax.text(px[i],py[i],pz[i],  '%s' % (str(i)), size=20, zorder=1,  color='k')
# Out:
# [[23 77 27 15 23]
#  [ 7 71 64 94 13]
#  [39 42 43 80  8]
#  [30 53 51 55 30]
#  [38 75 32 54 89]
#  [61  0 27  7 97]
#  [72 89 14 88 31]
#  [31  2 65 82 27]
#  [72  5 16 23  8]
#  [20 87 45 39 78]]
# summ
# 0---->123
# 1---->91
# 2---->89
# 3---->113
# 4---->202
# 5---->158
# 6---->192
# 7---->60
# 8---->85
# 9---->185

# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
print(x)

minx = []
miny = []


print('summ')
for i in range(len(x)):
  minx.append(x[i][2])
  miny.append(x[i][3])
 
  print(str(i)+"---->"+str(minx[i]+miny[i]))



plt.figure(figsize=(10,10))
plt.scatter(minx, miny, s= 100)
for i in range(len(x)):
  plt.annotate(str(i), (minx[i],miny[i]), size = 20)
# Out:
# [[76 13 98 93 28 70 42 39 72 24]
#  [49 59 94 61 63 92 77 14 15 88]
#  [23 57 26 88 76 67 12 46 51 62]
#  [99  4  9 89 72 67 14 64 31 98]
#  [20 40 23 29 76 81  4 82 56 10]
#  [34 31 94 42 27  6 66 11 72 15]
#  [36 97 80 73 58 91 66 33 36 76]
#  [58 80 93 76 96 75 87 30  8 84]
#  [53 77 62 15  0 25 46 35 20 63]
#  [49 40 43 87 59 60 41 34 89 90]]
# summ
# 0---->191
# 1---->155
# 2---->114
# 3---->98
# 4---->52
# 5---->136
# 6---->153
# 7---->169
# 8---->77
# 9---->130
